# %%
import os 
from pathlib import Path

ROOT = Path(__file__).resolve()

ROOT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import os
#       2 from pathlib import Path
# ----> 4 ROOT = Path(__file__).resolve()
#       6 ROOT
#
# NameError: name '__file__' is not defined
